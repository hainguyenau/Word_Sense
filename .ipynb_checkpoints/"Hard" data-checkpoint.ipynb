# %%
import numpy as np
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# ### Loading Data

# %%
with open('new_train/hard.cor') as f:
    for line in f.readlines():
        m = re.search("<s>(.*)<\/s>", line)
        if m:
            m2 = re.search("<tag \"(.*)\">(.*)<\/>", line)
            if m2:
                meaning = m2.group(1)
                word = m2.group(2)
                sentence = m.group(1)
                sentence = sentence.replace(m2.group(0), '')
                print word, meaning
                print sentence
                print '----'

# %% [markdown]
# Create a Dictionary for each type of HARD

# %%
with open('new_train/hard.cor') as f:
    d = {'HARD1':[], 'HARD2':[], 'HARD3':[]}
    
    for line in f.readlines():
        m = re.search("<s>(.*)<\/s>", line)
        if m:
            m2 = re.search("<tag \"(.*)\">(.*)<\/>", line)
            if m2:
                meaning = m2.group(1)
                word = m2.group(2)
                sentence = m.group(1)
                sentence = sentence.replace(m2.group(0), '')
                d[meaning].append(sentence)

# %%
print len(d['HARD1'])
print len(d['HARD2'])
print len(d['HARD3'])
# Out:
# 3455
# 502
# 376

# %% [markdown]
# Create a documents of all sentences, regardless of meaning

# %%
train_documents = [sentence for value in d.values() for sentence in value]
# [item for sublist in l for item in sublist]

# %%
len(train_documents)
# Out:
# 4333

# %%
type(train_documents[0])
# Out:
# str

# %% [markdown]
# ## Lemmatizing

# %%
import gensim.utils

# %%
def lem(documents):
    lem_documents = []
    for doc in documents:
        no_tag_words = [w[:-3] for w in gensim.utils.lemmatize(doc)]
        lem_documents.append(' '.join(no_tag_words)) 
    return lem_documents

# %%
lem_train_documents = lem(train_documents)

# %%
lem_train_documents[0]
# Out:
# 'lose popular support someone have kill defeat do'

# %% [markdown]
# ### TF-IDF

# %%
def Tfidf(documents):
    vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1,3)).fit(documents)
    vectors = vectorizer.transform(documents)
    return vectors, vectorizer

# %%
vectors, vectorizer = Tfidf(lem_train_documents)

# %%
vectorizer
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 3), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
vectors
# Out:
# <4333x73935 sparse matrix of type '<type 'numpy.float64'>'
# 	with 106933 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Agglomerative Clustering (slow, try later)

# %%
hr = AgglomerativeClustering(n_clusters = 3,\
                             affinity = 'cosine', linkage = 'average')

# %%
hr.fit(vectors.toarray())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-87-5d312dc8b5d0> in <module>()
# ----> 1 hr.fit(vectors.toarray())
#
# /home/misa/anaconda2/lib/python2.7/site-packages/scipy/sparse/compressed.pyc in toarray(self, order, out)
#     938     def toarray(self, order=None, out=None):
#     939         """See the docstring for `spmatrix.toarray`."""
# --> 940         return self.tocoo(copy=False).toarray(order=order, out=out)
#     941
#     942     ##############################################################
#
# /home/misa/anaconda2/lib/python2.7/site-packages/scipy/sparse/coo.pyc in toarray(self, order, out)
#     248     def toarray(self, order=None, out=None):
#     249         """See the docstring for `spmatrix.toarray`."""
# --> 250         B = self._process_toarray_args(order, out)
#     251         fortran = int(B.flags.f_contiguous)
#     252         if not fortran and not B.flags.c_contiguous:
#
# /home/misa/anaconda2/lib/python2.7/site-packages/scipy/sparse/base.pyc in _process_toarray_args(self, order, out)
#     815             return out
#     816         else:
# --> 817             return np.zeros(self.shape, dtype=self.dtype, order=order)
#     818
#     819     def __numpy_ufunc__(self, func, method, pos, inputs, **kwargs):
#
# MemoryError:

# %%
hr.labels_

# %%
np.bincount(hr.labels_)

# %% [markdown]
# ### LSA (not needed)

# %%
terms = vectorizer.get_feature_names()

# %%
lsa = TruncatedSVD(n_components=3, n_iter=100)

# %%
lsa.fit(vectors)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=3, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([  3.57578530e-04,   3.57578530e-04,   1.75950254e-03, ...,
#          6.64178733e-05,   9.81887023e-04,   9.81887023e-04])

# %%
for i, comp in enumerate(lsa.components_):
    termsInComp = zip(terms, comp)
    sortedTerms = sorted(termsInComp, key=lambda x:x[1], reverse=True)[:10]
    print
    print "Definition {}".format(i)
    print
    for term in sortedTerms:
        print term[0],term[1]
# Out:
# Definition 0
#
# say 0.858520318023
# time 0.207678846075
# make 0.130699933761
# work 0.122372523466
# believe 0.112140637236
# person 0.0957758618771
# thing 0.0913846805106
# know 0.0847157219489
# year 0.0741899806109
# just 0.0681002575173
#
# Definition 1
#
# time 0.59315204836
# work 0.297873739131
# believe 0.236515828503
# make 0.211861636655
# know 0.161117209931
# year 0.16005761853
# person 0.12537488547
# look 0.0954599211502
# just 0.091039995218
# tell 0.0765940247125
#
# Definition 2
#
# time 0.672428635773
# say 0.104738750404
# say say 0.0472741539846
# ababa 0.0206744521531
# child 0.0134730648086
# state 0.0132905975697
# coach 0.00806845794342
# say exactly 0.00730645675311
# deal 0.00720455653182
# turn 0.00638606652702

# %% [markdown]
# ### KMeans

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters = 3, n_init=100)
km.fit(vectors)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=3, n_init=100,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
km.labels_
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int32)

# %%
np.bincount(km.labels_)
# Out:
# array([3107,  379,  847])

# %% [markdown]
# ### Predict

# %%
sentence = 'This rock is hard'

# %%
def predict(sentence):
    vector = vectorizer.transform([sentence]) # use the vectorizer from training
    return km.predict(vector)

# %%
predict(sentence)
# Out:
# array([0], dtype=int32)

# %% [markdown]
# ## Create Data Frame (maybe don't need this section)

# %%
df1 = pd.DataFrame(d['HARD1'], np.repeat('HARD1', len(d['HARD1'])), columns=['text']).\
    reset_index().rename(columns = {'index': 'meaning'})
df2 = pd.DataFrame(d['HARD2'], np.repeat('HARD2', len(d['HARD2'])), columns=['text']).\
    reset_index().rename(columns = {'index': 'meaning'})
df3 = pd.DataFrame(d['HARD3'], np.repeat('HARD3', len(d['HARD3'])), columns=['text']).\
    reset_index().rename(columns = {'index': 'meaning'})

# %%
frames = [df1, df2, df3]
df = pd.concat(frames)

# %%
df.head()
# Out:
#   meaning                                               text
# 0   HARD1   `` He may lose all popular support ,  but som...
# 1   HARD1   Clever White House `` spin doctors '' are hav...
# 2   HARD1   I find it    to believe that the Sacramento R...
# 3   HARD1   Now when you get bad credit data or are confu...
# 4   HARD1   'A great share of responsibility for this nat...

# %%
print len(d['HARD1']), len(d['HARD2']), len(d['HARD3'])
# Out:
# 3455 502 376

# %% [markdown]
# The labels look correct. Let's do train test split

# %% [markdown]
# ## Train test split (with same ratio in each class)

# %%
from sklearn.cross_validation import train_test_split, cross_val_score

# %%
# train_df1 = df1.sample(frac=0.6)
# train_df2 = df2.sample(frac=0.6)
# train_df3 = df3.sample(frac=0.6)

# %%
X1 = pd.Series(d['HARD1'])
y1 = np.repeat('HARD1', len(d['HARD1']))

X2 = pd.Series(d['HARD2'])
y2 = np.repeat('HARD2', len(d['HARD2']))

X3 = pd.Series(d['HARD3'])
y3 = np.repeat('HARD3', len(d['HARD3']))

# %% [markdown]
# ## Scoring

# %%
score_hard1, score_hard2, score_hard3 = 0, 0, 0

for sent in d['HARD1']:
    if predict(sent) == 0:
        score_hard1 += 1
print "HARD1 score: ", score_hard1, '/', len(d['HARD1'])
print

for sent in d['HARD2']:
    if predict(sent) == 2:
        score_hard2 += 1
print "HARD2 score: ", score_hard2, '/', len(d['HARD2'])
print

for sent in d['HARD3']:
    if predict(sent) == 1:
        score_hard3 += 1
print "HARD3 score: ", score_hard3, '/', len(d['HARD3'])
print
# Out:
# HARD1 score:  2998 / 3455
#
# HARD2 score:  12 / 502
#
# HARD3 score:  12 / 376

# %%
predict("")
# Out:
# array([0], dtype=int32)

# %% [markdown]
# ## Try other words to see if more balanced ("serve", "interest")

# %%
with open('new_train/interest.cor') as f:
    for line in f.readlines():
        m = re.search("<s>(.*)<\/s>", line)
        if m:
            m2 = re.search("<tag \"(.*)\">(.*)<\/>", line)
            if m2:
                meaning = m2.group(1)
                word = m2.group(2)
                sentence = m.group(1)
                sentence = sentence.replace(m2.group(0), '')
                print word, meaning
                print sentence
                print '----'
# Out:
# interest interest_6
#  yields  on  money-market mutual funds  continued to slide , amid  signs  that  portfolio managers  expect  further declines  in     rates  .
# ----
# interest interest_6
#  longer maturities  are thought to indicate  declining    rates  because  they  permit  portfolio managers  to retain relatively  higher rates  for  a longer period  .
# ----
# interest interest_6
#  nevertheless , said  brenda malizia negus  ,  editor  of  money fund report  , yields `` may  blip  up again before  they   blip  down '' because of  recent rises  in  short-term    rates  .
# ----
# interest interest_5
#  j.p. bolduc  ,  vice chairman  of  w.r. grace  &  co.  ,  which  holds  a 83.4 %     in  this energy-services company  , was elected  a director  .
# ----
# interests interest_5
#  finmeccanica  is  an italian state-owned holding company  with      in  the mechanical engineering industry  .
# ----
# interest interest_6
#  in  august  ,  the commission  ruled that between  $ 190 million  and  $ 195 million  of  the plant 's construction cost  was unreasonable and should be refunded , plus      .
# ----
# interest interest_6
#  last month  ,  judge curry  set  the    rate  on  the refund  at  9 %  .
# ----
# interest interest_4
#  gary hoffman  ,  a washington lawyer  specializing in  intellectual-property cases  , said  the threat  of  u.s. retaliation  , combined with  a growing recognition  that protecting  intellectual property  is in  a country 's own     , prompted  the improvements  made by  south korea  ,  taiwan  and  saudi arabia  .
# ----
# interest interest_6
#  mr. rapanelli  recently has said  the government  of  president carlos menem  ,  who  took  office july 8  , feels  a significant reduction  of  principal  and      is  the only way   the debt problem  may be solved .
# ----
# interest interest_5
#  that stake  , together with  its convertible  preferred  stock holdings  , gives  faulding   the right  to increase  its     to  70 %  of  moleculon 's voting stock  .
# ----
# interest interest_1
#  the purchases  show  the strong     of  japanese investors  in  u.s. mortgage-based instruments  ,  fannie mae 's chairman  ,  david o. maxwell  , said at  a news conference  .
# ----
# interest interest_6
#  first ,  they  are designed to eliminate  the risk  of  prepayment --mortgage-backed securities  can be retired early if     rates  decline , and  such prepayment  forces  investors  to redeploy  their money  at  lower rates  .
# ----
# interest interest_6
#  at  the same time  ,  the drop  in     rates  since  the spring  has failed to revive  the residential construction industry  .
# ----
# interest interest_6
#  david berson  ,  economist  for  the mortgage bankers association  , predicted  the drop  in     rates  eventually will boost spending on  single-family homes  , but probably not until  early next year  .
# ----
# interest interest_6
#  the toronto-based real estate concern  said  each bond warrant  entitles  the holder  to buy  c$ 1,000 principal amount  of  debentures  at  par  plus accrued      to  the date  of  purchase  .
# ----
# interest interest_6
#  he  also said that after  the charges  , and `` assuming  no dramatic fluctuation  in     rates  ,  the company  expects to achieve  near-record earnings  in  1990  .
# ----
# interest interest_1
#  the fire  is also fueled by growing  international     in  japanese behavior  .
# ----
# interest interest_6
#  meanwhile ,  traders  in  tokyo  say that  the prospect  of  lower u.s.    rates  has spurred  dollar  buying by  japanese institutions  .
# ----
# interest interest_1
#  the market  again showed  little     in  further evidence  of  a  slowing  u.s. economy  , and  traders  note that  the market  in  recent weeks  has taken  its cues  more from  wall street  than  u.s. economic indicators  .
# ----
# interest interest_6
#  signs  of  a slowing economy  are increasing  pressure  on  the federal reserve  to cut  short-term    rates  , but  it  is n't clear whether  the central bank  will do so .
# ----
# interest interest_6
#  the fed  cut  the key federal funds    rate  by about  0.25 percentage point  to  8.75 %  after  the oct. 13 stock market plunge  , but has shown  no sign  of  movement  since .
# ----
# interest interest_6
#  ``  each day  that  congress  fails to act... will cause  additional disruption  in  our borrowing schedule  , possibly resulting in  higher    costs  to  the taxpayer  , ''  treasury secretary nicholas brady  said in  a speech  prepared for  delivery last night  to  a group  of  bankers  .
# ----
# interests interest_3
#  ``  we  believe that  it  is vitally important for  those japanese business     &lcub; in  the u.s  .
# ----
# interest interest_1
#  heightened japanese     in  american small business  parallels  an acceleration  of  investments  giving  japanese companies  control of  large  , highly  visible u.s. corporations  , such as  columbia pictures entertainment inc  .
# ----
# interest interest_5
#  last year  ,  mitsubishi international corp.  ,  the new york-based arm  of  mitsubishi corp.  , bought controlling      in  the glass company  in  a joint venture  with  ronald bodner  ,  a glass industry executive  and  mitsubishi consultant  .
# ----
# interest interest_1
#  adds takeshi kondo  ,  senior vice president  of  c. itoh america inc.  : ``  we  have  a great     in making  investments  , particularly in  new ventures  .
# ----
# interest interest_5
#  mr. klauser  says  mitsui  has  75 u.s. subsidiaries  in  which   it  holds  35 %     or  more  and  the trading company  hopes to double  the number  of  its u.s. affiliates  in  1990  .
# ----
# interest interest_6
#  for nearly  a decade  ,  banks  have competed for  customers  primarily with  the    rates they  pay on  their deposits  and  charge  on  their loans  .
# ----
# interest interest_6
#  wednesday  ,  november 1  ,  1989    the key u.s.  and  foreign annual    rates  below are  a guide  to  general levels  but do n't always represent  actual transactions  .
# ----
# interest interest_6
#  olympia broadcasting corp.  said  it  did n't make  a $ 1.64 million semiannual    payment due yesterday  on  $ 23.4 million  of  senior subordinated debentures  .
# ----
# interest interest_6
#  the united kingdom high court  declared  illegal a variety  of     rate swap transactions  and  options  deals between  a london borough council  and  commercial banks  .
# ----
# interest interest_6
#  at  one point  ,  hammersmith  is reported to have accounted for as much as  10 %  of  the sterling market  in     rate swap dealings  .
# ----
# interest interest_6
#  when  two parties  engage in  an    rate  swap ,  they  are betting against  each other  on  future rates  .
# ----
# interest interest_6
#  thus ,  an institution  obligated to make  fixed-rate    payments  on  debt  swaps  the payments  with  another  making  floating-rate payments  .
# ----
# interest interest_6
#  as     rates  rose ,  municipalities  owed  the banks  more than  the banks  were paying  them  .
# ----
# interest interest_1
#  ``  i  'm starting to see  more business transactions  , '' says  andrea west  of  american telephone  &  telegraph co.  , noting  growing     in  use  of  900 service  for  stock sales  ,  software tutorials  and even  service contracts  .
# ----
# interest interest_6
#  ``  i  'd much rather see  them  dealing with     rates  and  the deficit  .
# ----
# interest interest_6
#  there  is  $ 30.9 million  of  fourth series bonds  ,  the     on  which  is not subject to  the federal alternative minimum tax  .
# ----
# interest interest_4
#  its backers  fielded  every important     on  their team  --  a popular mayor  ,  the chamber  of  commerce  ,  the major media  -- and spent  $ 100,000  on  promotion  .
# ----
# interest interest_4
#  congress  could create  a compensation program  to help  such victims  while protecting  the national     in encouraging  new drugs  .
# ----
# interest interest_6
#  institutions  mostly remained on  the sidelines  because of  uncertainty regarding    rates  and  the dollar  .
# ----
# interest interest_1
#  due  to continuingly  high gold prices  tied to  uncertainty  about  the u.s. currency  ,  investor     was directed toward  oil  and  mining shares  ,  which traders  called  a  ``  defensive  ''  action  frequently taken when  the dollar  is expected to fall or during  times  of  inflation  .
# ----
# interest interest_1
#  dealers  said  most investor     was focused on  defensive blue-chip stocks  , particularly  those  with  limited u.k. exposure  .
# ----
# interest interest_6
#  total return  measures  price changes  and     income  .
# ----
# interest interest_6
#  the rating concern  said  the textile  and  clothing company 's    expense  exceeds  operating profit  `` by  a wide margin  '' and  it  noted united 's estimated  after-tax loss  of  $ 24 million  for  the year  ended  june 30  .
# ----
# interest interest_1
#  although  takeover experts  said  they  doubted  mr. steinberg  will make  a bid  by  himself  ,  the application  by  his reliance group holdings inc.  could signal  his     in helping revive  a failed labor-management bid  .
# ----
# interest interest_5
#  younkers management  is likely to buy  a 10 %  to  20 %     in  the chain  in  january  , said  fred s. hubbell  ,  equitable 's president  and  chief executive officer  .
# ----
# interests interest_3
#  reuters holdings plc  said  michael reupke  resigned as  general manager  to pursue  unspecified     ,  a move   the news organization  termed  an  ``  amicable separation  .
# ----
# interest interest_6
#  the company  also cited     costs  and  amortization  of  goodwill  as  factors  in  the loss  .
# ----
# interest interest_6
#  trading is expected to remain subdued as  the market  awaits  tomorrow 's release  of  the jobs data  with  the hope  that  it  will point toward  a decline  in     rates  .
# ----
# interests interest_5
#  meridian national corp.  said  it  sold  750,000 shares  of  its common stock  to  the mcalpine family     , for  $ 1 million  , or  $ 1.35   a share  .
# ----
# interest interest_6
#  the thrift  said that `` after  these charges  and assuming  no dramatic fluctuation  in     rates  ,  the association  expects to achieve near  record earnings  in  1990  .
# ----
# interest interest_6
#  the fed  is coming under  pressure  to cut  short-term    rates  due to  the apparent slowing  of  the economy  .
# ----
# interest interest_6
#  tuesday  ,  october 31  ,  1989    the key u.s.  and  foreign annual    rates  below are  a guide  to  general levels  but do n't always represent  actual transactions  .
# ----
# interests interest_4
#  it  was in  jaguar 's best     `` for  the company 's future  to be assured and  the present climate  of  uncertainty  resolved as quickly as  possible  , ''  mr. ridley  said .
# ----
# interest interest_1
#  the share price  was languishing at about  400 pence  before  ford 's sept. 19 announcement  of  its     in  a minority stake  .
# ----
# interest interest_6
#  the government  , already buffeted by  high    rates  and  a slowing economy  , has been badly hurt by  last week 's shake-up  in  mrs. thatcher 's cabinet  .
# ----
# interests interest_3
#  ``  he  is going to pursue  other     , ''  mr. jahn  said .
# ----
# interest interest_1
#  but  other sectors  failed to attract  investor     and remained  sluggish  , making  overall  trading appear mixed .
# ----
# interest interest_6
#  first ,  he  said ,  domestic    rates  are likely to stay at  higher levels  as increased  anticipation  of  inflation  followed rising  consumer prices  reported  last week  .
# ----
# interest interest_6
#  the cd trend  runs counter to  the direction  of  short-term    rates  at  the treasury bill auction monday  .
# ----
# interest interest_6
#  but when  market    rates  move up rapidly ,  increases  in  bank cd  yields sometimes lag .
# ----
# interests interest_5
#  fraser  &  neave  ,  which  also has      in packaging ,  beer  and  dairy products  , holds  the coke licenses  for  malaysia  and  brunei  , where  per-capita consumption  is n't as high as in  singapore  .
# ----
# interest interest_6
#  moody   's investors service inc.  said  it  lowered  the ratings  on about  $ 3.2 billion  of  houston lighting  &  power co. 's securities  because of  the company 's low levels  of     coverage  and  internal cash generation  .
# ----
# interest interest_6
#  the remainder  expect  a downturn  to begin sometime in  although  manufacturers  often are quick to call for  lower    rates  ,  60 %  of  the executives  said  they  would prefer that  the fed  keep inflation-fighting as  its top priority  even if  that  means  higher rates  .
# ----
# interest interest_6
#  the other 40 %  said  the fed  ought to worry  less  about  inflation  and bring     rates  down .
# ----
# interest interest_6
#  the average    rate  rose to  8.3875 %  at  citicorp 's $ 50 million weekly auction  of  91-day commercial paper  , or  corporate ious  , from  8.337 %  at  last week 's sale  .
# ----
# interest interest_1
#  the fbi  initially showed  little     , and  he  had  the impression other federal security agencies  were tangled up in  legal red tape  .
# ----
# interest interest_1
#  one  of  its international specialists  ,  steve white  , took  a quick     in  mr. stoll 's hunt  , ultimately tracing  the hacker  to  west germany  .
# ----
# interest interest_6
#  but  higher    rates  paid on  off-budget debt  could add  billions  to  the bailout  costs , and would n't be subject to  congressional scrutiny  ,  ways  and  means members  argued .
# ----
# interests interest_5
#  the lumber  ,  insulation  and  fireproofing concern  said  the transaction  ,  which  includes  a swap  of  other timber     , would result in  a $ 13.5 million after-tax  gain , to be recorded in  the fourth quarter  .
# ----
# interest interest_6
#  a spokesman  said  healthvest  has paid  two  of  the three banks   it  owed      to in  october  and is in  negotiations  with  the third bank  .
# ----
# interest interest_5
#  the loan  is backed by  healthcare 's 5.4 % stake  in  healthvest  and      in  certain facilities  .
# ----
# interest interest_5
#  prosecutors  , in  an indictment  based on  the grand jury 's report  , maintain that at  various times  since  1975  ,  he  owned  a secret  and  illegal     in  a beer distributorship  ; plotted hidden  ownership *interests  in  real estate   that  presented  an alleged conflict  of  *interest  ; set up  a dummy corporation  to buy  a car  and obtain  insurance  for  his former girlfriend  ( now  his second wife  ) ; and maintained  54 accounts  in  six banks  in  cambria county  .
# ----
# interests interest_5
#  prosecutors  , in  an indictment  based on  the grand jury 's report  , maintain that at  various times  since  1975  ,  he  owned  a secret  and  illegal *interest  in  a beer distributorship  ; plotted hidden  ownership     in  real estate   that  presented  an alleged conflict  of  *interest  ; set up  a dummy corporation  to buy  a car  and obtain  insurance  for  his former girlfriend  ( now  his second wife  ) ; and maintained  54 accounts  in  six banks  in  cambria county  .
# ----
# interest interest_6
#  it  refinanced  the judge 's loan  , lowered  its    rate  and accepted  a trade-in   that  had n't originally been  part  of  the deal  --  a beat  up  1981 chevy citation   the dealer  had to repair before  it  could be resold .
# ----
# interest interest_6
#  two years  later ,  he  wrote to complain that  the      he  was paying on  an unsecured $ 10,000 loan  was `` absolutely onerous .
# ----
# interest interest_6
#  the group 's bid  for  $ 40.9 million  of  wastewater treatment  insured  bonds  ,  series 1989   a  , produced  a 7.0826 % true    cost  .
# ----
# interest interest_6
#  the group 's bid  for  $ 34.2 million  of  wastewater treatment bonds  ,  series 1989 b  , produced  a 7.0808 % true    cost  .
# ----
# interest interest_6
#      on  the bonds  will be treated as  a preference item  in calculating  the federal alternative minimum tax   that  may be imposed on  certain investors  .
# ----
# interest interest_6
#  but  it  marks  a big change  for  the japanese  ,  who  shunned  mortgage securities  after getting burned by  a big downturn  in      rates  a few years  back .
# ----
# interest interest_1
#  ``  you  ca n't say  it  's  a  ``  tsunami  '' (  tidal wave  ) , but  we  're making  some headway  , '' says  fannie mae 's chairman  ,  david o. maxwell  ,  who  visits  tokyo  at  least  once  a year  to explain and drum up  investor     in  mortgage securities  .
# ----
# interest interest_1
#  ``      is  a great deal  higher than  it  was  a year  ago .
# ----
# interest interest_6
#  '' ultimately ,  he  says ,  strong demand  could help to drive down     rates  on  mortgage securities  .
# ----
# interest interest_6
#  compounding  the trouble  to  japanese investors  ,  mortgage securities  pay      monthly , since  most mortgages  require  homeowners  to make  monthly payments  .
# ----
# interests interest_4
#  supporters  of  poison pills  argue  that their adoption  forces  bidders  to negotiate with  a corporation 's directors  ,  who  are thereby put in  a better position  to pursue  the long-term     of  the corporation  .
# ----
# interests interest_5
#  enfield  is  a holding company  with      in manufacturing  concerns  .
# ----
# interest interest_1
#  odds  and  ends   despite  growing     in  the environment  ,  u.s. consumers  have n't shown  much *interest  in  refillable packages  for  household products  .
# ----
# interest interest_1
#  odds  and  ends   despite  growing *interest  in  the environment  ,  u.s. consumers  have n't shown  much     in  refillable packages  for  household products  .
# ----
# interest interest_6
#  they  pay      only for  115 months  , with  principal payments  beginning thereafter .
# ----
# interest interest_6
#  a number  of  those  polled predict  the dollar  will slip as  the federal reserve eases    rates  .
# ----
# interest interest_6
#  in  last month 's survey  ,  a number  of  currency analysts  predicted  the dollar  would be  pressured  by  a narrowing  of     rate differentials  between  the u.s.  and  west germany  .
# ----
# interest interest_6
#  after  a  surprisingly  sharp  widening in  the u.s. august merchandise trade deficit  --  $ 10.77 billion  from  a revised $ 8.24 billion  in  july  and well above  expectations  -- and  a startling 190-point drop  in  stock prices  on  oct. 13  ,  the federal reserve  relaxed  short-term    rates  , knocking  fed funds  from around  9 %  to  8 34 %  .
# ----
# interest interest_6
#  but  predictions  that  central banks  of  the group  of  seven  (  g-7  )  major industrial nations  would continue  their massive dollar sales  went astray , as  the market  drove  the dollar  downward on  its own  , reacting to  wall street 's plunge  and  subsequent price volatility  ,  lower u.s.    rates  and  signs  of  a  slowing  u.s. economy  .
# ----
# interest interest_6
#  but ,  mr. kakita  added , once  u.s. equities  regain  some stability  ,  players  will move back into  dollar-denominated investments  , especially  treasury bonds  ,  whose value  rises when     rates  decline .
# ----
# interest interest_6
#  he  said  he  expects  u.s.    rates  to decline , dragging  the dollar  down to around  1.80 marks  by  the end  of  january  after  a short-lived dash  to  1.87 marks  by  the end  of  november  .
# ----
# interest interest_6
#  west german    rates  ,  he  said , will remain  unchanged  .
# ----
# interest interest_6
#  ``  we  're finally seeing  the culmination  of  all the recessionary buildup  of  the last few months  , ''  he  said , noting  a  continuing  downward trend  in  u.s.    rates  ,  a shaky stock market  and ``  gloomier economic times  ahead ''  all  signal  a  significantly  lower dollar  .
# ----
# interest interest_6
#  the head trader  of  chemical banking corp. 's    rate options group  has left  the company  , following  valuation errors   that  resulted in  a $ 33 million charge  against  its third-quarter results  .
# ----
# interest interest_6
#  in  other personnel changes  stemming from  problems  in  its options unit  :  --  chemical  named  james kennedy  ,  a trader  in  swaps contracts  for  the bank  , to assume  mr. edelson 's duties  and to be trading  manager  for  derivative products  , including  swaps  and     rate options  .
# ----
# interest interest_6
#  the spokeswoman  said  the frankfurt situation  was `` totally  different  '' from  problems  in  the    rate options unit  .
# ----
# interest interest_6
#  according to  individuals  familiar with  the situation  ,  the frankfurt loss  stemmed from  a computer program  for calculating  prices  on  forward-rate agreements   that  failed to envision  an    rate environment  where  short-term rates  were equal to or higher than  long-term rates  .
# ----
# interest interest_6
#  while  the incidents  involving     rate options  and  forward-rate agreements  are unrelated ,  some observers  say  they  echo  a 1987 incident  in  which   bankers trust new york corp.  restated  the value  of  its foreign exchange options  contracts downward by about  $ 80 million  .
# ----
# interest interest_6
#  in  an    rate options contract  ,  a client  pays  a fee  to  a bank  for  custom-tailored protection  against  adverse *interest rate swings  for  a specified period  .
# ----
# interest interest_6
#  started  three years  ago ,  chemical 's    rate options group  was  a leading force  in  the field  .
# ----
# interest interest_6
#  started  three years  ago ,  chemical 's    rate options group  was  a leading force  in  the field  .
# ----
# interest interest_1
#  after  20 years  of  pushing labor proposals  to overhaul  the nation 's health-care system  ,  bert seidman  of  the afl-cio  is finding      from  an unlikely quarter  :  big business  .
# ----
# interest interest_1
#  some analysts  are cynical about  the new corporate     in  health-care overhaul  .
# ----
# interest interest_6
#  unless   the federal reserve eases    rates  soon to stimulate  the economy  ,  profits  could remain  disappointing  .
# ----
# interests interest_5
#  bouygues s.a.  ,  a diversified construction concern  based in  paris  , said  its consolidated profit  for  the 1989 first half  , after  payments  to  minority     , surged to  188 million french francs  (  $ 30.2 million  ) from  65 million francs   a year  earlier .
# ----
# interests interest_5
#  for  all  of  1988  ,  bouygues  had consolidated  profit  of  519 million francs  , after  payments  to  minority     , on  revenue  of  50 billion francs  .
# ----
# interest interest_6
#  ``  the    rate sensitives  are n't rallying with  the rest  of  the market  because of  fears  about  what   the  (  federal reserve  ) will do , ''  mr. jennison  said .
# ----
# interest interest_6
#  he  said that  investors  will scour  the october employment report  ,  due  out  friday  , for  clues  about  the direction  of  the economy  and  the immediate outlook  for     rates  .
# ----
# interests interest_3
#  the separate $ 67 billion bill  sent to  the white house  had  budget difficulties  , too , but was saved ultimately by  its importance  to  a broad spectrum  of      in  congress  and  the administration   itself  .
# ----
# interest interest_5
#  the dallas oil  and  gas concern  said that  $ 10 million  of  the facility  would be used to consolidate  the company 's $ 8.1 million  of  existing bank debt  , to repurchase  4 million  of  its 4.9 million shares  outstanding of  series d convertible preferred stock  , and to purchase  a 10 % net-profits     in  certain oil  and  gas properties  from  one  of  its existing lenders  ,  national canada corp  .
# ----
# interest interest_6
#  ted eubank  ,  coda 's president  , said  the loan  carries  an    rate  of  prime  plus  one percentage point  , with  85 %  of  the company 's net oil  and  gas revenue   each month  dedicated to  repayment  .
# ----
# interest interest_5
#  santa fe  has disclosed that  it  is negotiating to sell  a 20 %     in  its real estate unit  to  the california public employees retirement system  for roughly  $ 400 million  .
# ----
# interest interest_5
#  profit  after  tax  and  minority     but before  extraordinary items  rose  12 %  to #  135.2 million  ;  per-share earnings  rose to  five pence  from  4.5 pence  .
# ----
# interest interest_5
#  ''   mr. meek  said  his suspicions  were aroused by  several foreign investments  by  lincoln  , including  $ 22 million  paid to  credit suisse  of  switzerland  ,  an $ 18 million     in  saudi european bank  in  paris  ,  a $ 17.5 million investment  in  a bahamas trading company  , and  a  recently discovered holding in  a panama-based company  ,  southbrook holdings  .
# ----
# interest interest_1
#  he  noted that  institutional investors  showed `` pretty general ''      in  stocks  in  the latest session  .
# ----
# interests interest_5
#  ogden projects  ,  which  has      in  solid-waste recovery  and  hazardous-waste cleanup  , said  it  has  13 facilities  in  operation  , up from  seven   a year  ago .
# ----
# interests interest_5
#  meanwhile ,  ogden corp.  ,  which  also has      in  building maintenance  and  management  , reported  third-quarter net income  of  $ 27.1 million  , or  67 cents   a share  , more than twice  the $ 13.5 million  , or  34 cents   a share  ,  a year  earlier .
# ----
# interests interest_3
#  ``  his  &lcub;  phelan 's  &rcub;  own     are in building  an electronic marketplace  , '' said  a market maker  .
# ----
# interest interest_6
#  economists  said  the report  raised  speculation  that  the economic slowdown  could turn into  a recession  ,  which  would pave  the way  for  the federal reserve  to lower     rates  .
# ----
# interest interest_6
#  some analysts  believe  the company  has  the ability  to pinpoint  the trough  in     rate cycles  .
# ----
# interest interest_6
#  in  october 1979  , just  days  before  the federal reserve  raised     rates  ,  ibm  offered  $ 1 billion  in  debt securities  .
# ----
# interest interest_6
#  west german bonds  firmed  a bit  after  monday 's fall  , but  traders  said  the market  remains  bearish due  to  speculation  that     rates  could rise again .
# ----
# interest interest_6
#  his comments  were interpreted as  a sign  that  higher    rates  are possible .
# ----
# interest interest_1
#  still ,  a lot  of  investors  clearly have revived  their     in  gold  and  utility shares  .
# ----
# interest interest_6
#  ''  `` if  the fed  does not come to  the rescue  and produce  lower short-term    rates  over  the next 30 days  ,  the market  's going to flounder , '' says  larry wachtel  ,  a market analyst  with  prudential-bache securities  .
# ----
# interest interest_1
#  although  daimler  has said  it  is n't *interested in mounting  a bid  for  jaguar  ,  dealers  said  its name  further underlined  the growing     in  the british concern  .
# ----
# interest interest_6
#  takamori matsuda  ,  an analyst  at  dresdner-abd securities  , said  fading expectation  for  lower    rates  made  investors  step back from  real-estate shares  ,  which  advanced  last week  .
# ----
# interest interest_1
#  for almost  any peruvian   these days  , to show  an     in  public office  is  a heroic gesture  ; for  mr. vargas llosa  especially so , since  he  already has achieved  a high position  in  the world 's eyes  as  a writer  .
# ----
# interest interest_5
#  the four seasons spokeswoman  said  mr. sharp  ,  who  has  an 81 % voting stake  in  the company  , has  no current plans  to sell  his     .
# ----
# interests interest_5
#  rockefeller group  said in  september   it  would seek  investors  to purchase as much as  80 %  of  the firm  ,  a holding company  for  rockefeller family     .
# ----
# interest interest_1
#  selected  blue-chip issues  attracted buying      , however , and  the dow jones industrial average  stayed in  positive territory  throughout  the entire session  .
# ----
# interest interest_6
#  the realization  that     rates  will be firm due to  excessive demand  for  credit  on  the part  of  the federal government  ( including  off-balance sheet requirements  ) and  leveraged buyout  related  transactions  .
# ----
# interest interest_6
#  one  can magnify  this problem 10 times  for highly  leveraged companies whose revenues  are slowing and where     rates  are no longer  accommodative  , in  bifurcated credit markets  .
# ----
# interest interest_6
#  a dollar   that  will slide into  year end  -- due to  international    rate differentials  and  the choreographed   trading techniques  of  certain oil importers  --  which  does not inspire  foreign-investor *interest  .
# ----
# interest interest_1
#  a dollar   that  will slide into  year end  -- due to  international *interest rate differentials  and  the choreographed   trading techniques  of  certain oil importers  --  which  does not inspire  foreign-investor     .
# ----
# interest interest_6
#  the loan  ,  which  carries  a 9.65 % annual    rate  , was approved after  scientific-atlanta  won  a $ 29.4 million contract  to supply  equipment  and  services  for  the project  in  chile  .
# ----
# interest interest_6
#  short-term    rates  rose at  the government 's regular weekly treasury-bill auction  .
# ----
# interest interest_6
#  here are  details  of  yesterday 's 51-day cash management bill auction  :      rate 8.07 %   the bills  are dated  oct. 31  and  mature dec. 21  ,  1989  .
# ----
# interest interest_6
#  in  june  ,  western union  was forced to reset  the    rate  on  the senior secured notes  due in  1992  to  19 14 %  from  16 12 %  ,  a move   which  increased  the firm 's annual *interest payments  by  $ 13.8 million  .
# ----
# interest interest_6
#  in  june  ,  western union  was forced to reset  the *interest rate  on  the senior secured notes  due in  1992  to  19 14 %  from  16 12 %  ,  a move   which  increased  the firm 's annual    payments  by  $ 13.8 million  .
# ----
# interest interest_1
#  ``  my impression  is that  there  is n't  anything   which  arouses  our     at  first glance  , '' says  an official  from  japan 's ministry  of  international trade  and  industry  .
# ----
# interest interest_1
#  the survey  also detected  a bit more     in  golf  ,  a positive sign  for  country clubs  and  golf club makers  .
# ----
# interest interest_6
#  the central bank  also unexpectedly raised  the base rate  by  half a percentage point  to  3.75 % oct. 11  as  part  of  an inflation-fighting move   that  indirectly increases     rates  charged on  new home construction loans  .
# ----
# interest interest_6
#  analysts  also say  it  's inevitable that  brazil  will seek to renegotiate  its $ 115 billion foreign debt  , on  which   it  suspended     payments last month  .
# ----
# interests interest_3
#  it  reflects  values  of  a generation   that  wants  more time  for  families  and  personal     , says  john h. moxley iii  ,  who  directs  physician-executive searches  for  kornferry international  .
# ----
# interest interest_1
#  the approach  has generated  so much     that  nyu  is  host  to  the first conference  on  cooperative care nov. 30  .
# ----
# interest interest_1
#  investor     in  stock funds  ``  has n't  stalled at  all  , ''  mr. hines  maintains .
# ----
# interest interest_4
#  ''   it  is in  the western     to see  mr. gorbachev  succeed .
# ----
# interest interest_1
#  revco  insists that  the proposal  is simply  an  ``  expression  of      , '' because under  chapter 11 revco  has ``  exclusivity rights  '' until  feb. 28  .
# ----
# interests interest_4
#  to ensure  the loyalty  of  the business sector  ,  mr. gorbachev  may offer  concessions  and  powers   that  will allow  the business community  to preserve  its own     , probably by  restricting competition  .
# ----
# interest interest_6
#  quotron  is n't profitable on  citicorp 's books  because of  the     charges  the new york bank holding company  incurred in buying  the financial-data concern  for  $ 680 million  , says  ronald i. mandle  ,  analyst  for  sanford c. bernstein  &  co  .
# ----
# interest interest_2
#  abc 's baseball experience  may be of      to  cbs inc.  ,  which   next season  takes over  the broadcasting  of  all baseball playoffs  in  a four-year television contract  priced at  $ 1.06 billion  .
# ----
# interest interest_1
#  but      instead decreased .
# ----
# interest interest_1
#  but      waned as  the day  wore on and  investors  looked ahead to  the release  later  this week  of  two important economic reports  .
# ----
# interest interest_6
#  monday  ,  october 30  ,  1989    the key u.s.  and  foreign annual    rates  below are  a guide  to  general levels  but do n't always represent  actual transactions  .
# ----
# interest interest_6
#  annualized     rates  on  certain investments  as reported by  the federal reserve board  on  a weekly-average basis  :   a-discounted rate  .
# ----
# interest interest_6
#  western union  had said  two weeks  ago that  it  might withdraw  the pending offer  ,  which  would have replaced  $ 500 million  in  so-called reset notes  , now paying  19.25 % annual     and set to come due in  1992  , with  two new issues  paying  lower *interest  .
# ----
# interest interest_6
#  western union  had said  two weeks  ago that  it  might withdraw  the pending offer  ,  which  would have replaced  $ 500 million  in  so-called reset notes  , now paying  19.25 % annual *interest  and set to come due in  1992  , with  two new issues  paying  lower     .
# ----
# interest interest_6
#  the notes  became  burdensome  when  reset provisions  allowed  their    rate  to be raised to  19.25 % last june  .
# ----
# interest interest_6
#  western union  had offered to swap  each $ 1,000 face amount  of  the notes  for  six shares  of  common stock  and  two new debt issues  :  a $ 500 note  paying  an    rate  starting at  16.75 %  annually and rising in  later years  , due in  1992  , and  a $ 500 note  , due in  1997  , paying  a fixed rate  of  17 %  and  including rights  protecting  a holder  against  a decline  in  the trading price  of  the bond  .
# ----
# interest interest_6
#  western union  must make  $ 48 million  in     payments  on  the reset notes  on  dec. 15  , and  a company spokesman  said  it  fully intends to meet  the payments  .
# ----
# interest interest_6
#  but  western union  has said  it  must lower  the    rate  on  its debt  to regain  full financial health  .
# ----
# interests interest_4
#  munich-based allianz 's brief explanatory statement  said  it  is acting to protect  its own     as  a shareholder  of  navigation mixte  .
# ----
# interest interest_5
#  allianz  said in  its statement  that  it  was acting to protect  that     ,  which  ties  it  to  navigation mixte  as  a partner  .
# ----
# interests interest_5
#  fletcher challenge ltd.  said  its petrocorp unit  agreed to acquire  certain alberta oil  and  gas     from  amoco corp. 's canadian unit  , for about  130 million canadian dollars  (  us$ 110.6 million  ) .
# ----
# interest interest_6
#  mercury  attributed  the loss  to  rapid prepayments  of  loans  and  costs  incurred in refinancing  many house loans   this past spring  and  summer  , when     rates  dipped .
# ----
# interests interest_5
#  james river  ,  a maker  of  pulp  ,  paper  and  plastic products  , already has      in  tissue businesses  in  france  ,  spain  ,  italy  and  turkey  .
# ----
# interest interest_6
#  comments  by  john major  ,  who  has succeeded  mr. lawson  , also failed to damp  market concern  , despite  his pledge  to maintain relatively  high british    rates  .
# ----
# interest interest_6
#  according to  one london-based analyst  , even  higher    rates  wo n't help  the pound  if  britain 's government  continues to appear  unstable  .
# ----
# interest interest_5
#  rockefeller group  agreed to sell  a 51 %     to  mitsubishi estate  ,  a major japanese developer  and  property owner  , for  $ 846 million  .
# ----
# interest interest_5
#  cray research  will retain  a 10 %     in  the new company  ,  which  will be based in  colorado springs  ,  colo  .
# ----
# interest interest_6
#  bio-technology  ,  a new york maker  of genetically engineered  products  for  human  and  animal health care  , said  it  made  the exchange  offer to reduce  its    payments  .
# ----
# interest interest_4
#  of  course these turf battles  are unseemly ,  wasteful  and potentially dangerous and should be resolved in  the     of  national security  , but  mr. lehman  seems to be  part  of  the problem  rather than  part  of  the answer  .
# ----
# interests interest_3
#  mr. corr  resigned to pursue  other business     ,  the airline  said .
# ----
# interest interest_1
#  cincinnati-based p&g  took  an     ;  it  ordered  two studies  on  psyllium  and  cholesterol  .
# ----
# interest interest_1
#  with      in  emigration  and  investment  abroad soaring since  june 4  ,  that assumption  no longer seems so safe .
# ----
# interest interest_6
#  net    income  for  the third quarter  declined to  $ 35.6 million  from  $ 70.1 million   a year  ago .
# ----
# interest interest_6
#  the bonds  will be issued for  a term  of  34 years  at  an    rate  of  8 %  .
# ----
# interest interest_6
#  the manufacturers hanover corp. unit  ,  which  is seeking  repayment  of  a $ 36 million loan  , has asked  the court  to give  its claim priority  over  that  of  minpeco  ,  which  won  a $ 132 million judgment  against  mr. hunt  ,  his brother nelson bunker hunt  and  other defendants last year  in  a case  stemming from  their alleged attempts  to corner  the silver market  in  while claiming that  penalties  ,  legal fees  and      have driven  the value  of  its claim  to  more  than  $ 250 million  ,  minpeco  has agreed to settle for  an allowed claim  of as much as  $ 65.7 million  .
# ----
# interest interest_6
#  automatic data  is redeeming  the bonds  because  the after-tax cost  of  the     on  the bonds  is higher than  the dividend yield  on  the common  ,  a spokesman  said .
# ----
# interest interest_1
#  one thing  's for  sure  :  there  have been  a ton  of  them  , and  greater beings  than  the editors  of  the national enquirer  have shown      .
# ----
# interest interest_6
#  but more recently ,  the pound  has been falling with  high inflation  ,  which  has also seemed almost impervious to  the high     rates  mr. lawson  deployed to stop  it  .
# ----
# interest interest_6
#  mr. reynolds  also notes that since  british banks  have  no reserve requirements  ,  high    rates  are less likely to curb  inflation  than to cause  recession  .
# ----
# interest interest_6
#  our advice  is  this  : immediately return  the government surpluses  to  the economy  through  incentive-maximizing tax  cuts , and find  some monetary policy target   that  balances  both supply  and  demand  for  money  (  which   neither   aggregates  nor     rates  can do ) .
# ----
# interests interest_3
#  while  mr. roman  is  a workaholic detailsman  ,  mr. phillips  would rather delegate , leaving  him   time  for  his     outside  the office  .
# ----
# interest interest_6
#  the company 's earnings  before      ,  taxes  and  depreciation  ,  which bondholders  use  a measurement  of  the chain 's ability  to pay  its existing debt  , increased  11 %  in  fiscal 1989  to  $ 926.1 million  from  $ 833.6 million  .
# ----
# interest interest_6
#  excluding  those businesses  ,  earnings  before      ,  taxes  and  depreciation  for  1988  would have been  $ 728.5 million  .
# ----
# interests interest_5
#  financial analysts  note that  mr. rey  is attracted to  companies   that  are undervalued on  the basis  of  their real-estate     .
# ----
# interest interest_6
#  that  means  unisys  must pay about  $ 100 million  in       every quarter  , on  top  of  $ 27 million  in  dividends  on  preferred stock  .
# ----
# interest interest_6
#  it  said  long-term    rates  , then above  9 %  , could drop to  7 %  by  the end  of  1989  , so  bonds  ,  which  benefit from falling  rates  , would be  a good buy  .
# ----
# interest interest_6
#  a good half-hour  into  breakfast  at  the palmer house  ,  mr. o'brien  looks up from  his plate  after  mr. straszheim  says  something  about  people   who  believe     rates  are about to nosedive .
# ----
# interest interest_6
#  ''  he  says  the economy  , and especially  the employment numbers  , look much better than  he  expected ;     rates  have generally declined ;  inflation has n't  run amok .
# ----
# interest interest_6
#  to keep  the exchange rate  pegged ,  mr. lawson  tightened  monetary policy  and pushed     rates  up to  15 %  .
# ----
# interest interest_6
#  this  doubled  the mortgage    rates  of  the many new homeowners  that  mrs. thatcher 's policies  had created , producing  widespread disaffection  and  pushing labor  ahead in  the polls  .
# ----
# interest interest_6
#  consequently ,  mr. lawson  saddled  mrs. thatcher  with  a record trade deficit  , renewed  inflation  and  high    rates  --  three political failures  in  a row  .
# ----
# interest interest_6
#  the most important governments  have ignored  the role  of  low tax rates  in attracting  real capital investment  , instead emphasizing  financial flows  in  response  to  high    rates  .
# ----
# interest interest_6
#  then , when  the currency  falls ,     rates  are raised to attract  financial flows  in  order  to stabilize  the exchange rate  .
# ----
# interests interest_5
#  ra  acquired  the howick coal mine oct. 20  when  it  bought  british petroleum co. 's australian coal     for  $ 275 million  .
# ----
# interest interest_1
#  rather  ,  mr. perlman  said ,  control data  intends to bid for  the  coming  minnesota lottery contract  and is seeking  new applications  for  the technology  overseas , where ``  there  is  great     in  games  of  skill  .
# ----
# interest interest_6
#  underscoring  the size  of  the deficits  of  the past few years  ,  the treasury report  showed that for  the first time     paid on  the public debt  --  $ 240.86 billion  -- exceeded  spending  on  social security  ,  the single largest government program  .
# ----
# interest interest_6
#  accrued      on  the refund  was about  $ 18 million  as of  oct. 25  .
# ----
# interest interest_6
#  humana inc.  said  it  expects to receive about  $ 27 million  in  federal income-tax refunds  and      from  a court  ruling on  a tax dispute  .
# ----
# interest interest_5
#  in  addition  ,  new york-based lin  would exercise  its right  to buy out for  $ 1.9 billion   the 55 % equity     of  its partner  ,  metromedia co.  , in  a new york cellular franchise  .
# ----
# interest interest_6
#  although  he  expressed  confidence  that  the proposed new company 's cash flow  would be sufficient to cover     payments  on  the debt  ,  he  estimated that  the company  would n't be profitable until  1994  or later .
# ----
# interest interest_5
#  in  response  to  bellsouth 's amended pact  ,  the kirkland  ,  wash.  ,  company  extended  its own offer  to buy  22 million lin shares  for  $ 125  apiece ,  which  would give  mccaw   a 50.3 % controlling     .
# ----
# interest interest_5
#  ''  under  its revised proposal  ,  atlanta-based bellsouth  would have  a 50 %     in  the new cellular company  and would be responsible for  half  of  its debt  .
# ----
# interest interest_4
#  urging lin directors  to conduct ``  a fair auction  on  a level playing field  , ''  mccaw  asked how well  the public     would be served `` with  the bell  operating  companies  controlling over  94 %  of  all cellular  &lcub;  potential customers  &rcub; in  the nation 's top 10 markets  .
# ----
# interest interest_1
#  traders  said that selling  pressure was n't  enormous and that  the dax  dropped  friday more  on  a lack  of  any substantial buying     .
# ----
# interest interest_6
#  she  could end up seeking  a fourth term  in  an economy  sick with  inflation  ,  high    rates  and  a heavy trade deficit  .
# ----
# interest interest_6
#  of  immediate concern  is whether  the thatcher government  will continue  mr. lawson 's policy  of tracking  the monetary policies  of  the west german bundesbank  and responding in  kind  when  the frankfurt authorities  move     rates  .
# ----
# interest interest_6
#  a state trial judge  in  illinois  gave  preliminary approval  to  a proposed settlement  of  a suit  against  a bank  of  new york co. unit  ,  irving trust co.  , over  the    rates  on  irving 's former one wall street account money-market deposit accounts  .
# ----
# interest interest_6
#  the plaintiffs  accused  irving  of paying  less     than promised in  a marketing brochure  .
# ----
# interest interest_6
#  and , by  the end  of  that week  ,  the key federal funds    rate  ,  which  is largely controlled by  the fed  , had settled at  8.75 %  , barely changed from  the level  of just under  9 %   that  prevailed  the previous week  .
# ----
# interest interest_4
#  and  judge newman  ,  a former patent lawyer  , wrote in  her dissent  when  the court  denied  a motion  for  a rehearing  of  the case  by  the full court  , ``  the panel 's judicial legislation  has affected  an important high-technological industry  , without  regard  to  the consequences  for  research  and  innovation  or  the public     .
# ----
# interest interest_6
#  friday  ,  october 27  ,  1989    the key u.s.  and  foreign annual    rates  below are  a guide  to  general levels  but do n't always represent  actual transactions  .
# ----
# interest interest_2
#  although  that  may sound like  an arcane maneuver  of  little     outside  washington  ,  it  would set off  a political earthquake  .
# ----
# interest interest_1
#  republicans  have  as much     as  democrats  in ``  the way   the system  works , ''  he  notes .
# ----
# interest interest_6
#  the government  had fallen  $ 300 million  behind in     payments  .
# ----
# interest interest_6
#  the remainder  of  the debt  will be exchanged for  new costa rican bonds  with  a 6 14 %    rate  .
# ----
# interest interest_6
#  the industrial revolution  has produced  an explosion  in  the capital market  ,  which  is  a far cheaper source  of  funds  than  government-controlled banks  , where     rates  for  prime borrowers  are around  16 %  .
# ----
# interest interest_4
#  one person  close to  the process  says  it  would not be in  the best     of  cbs news  to comment on  a  ``  work  in  progress  , '' such as  the hoffman re-creation  , but says  cbs news  is ``  aware  '' of  the concerns  of  ms. lawrenson  and  mr. hoffman 's former wife  .
# ----
# interest interest_6
#  leaseway transportation corp.  said  it  will  restructure $ 192.5 million  of  certain subordinated debentures  to reduce  its debt obligations  and     expense  .
# ----
# interest interest_6
#  but  the proposed transaction  calls for  an exchange  of  the debt  for  new debentures  of  lower face value  and reduced  cash     .
# ----
# interest interest_5
#  also ,  debt holders  would be offered  an equity position  in  leaseway  ,  which  in  total  would represent  a controlling     in  the company  .
# ----
# interest interest_1
#  he  noted that for  the first time  in  months   there  was  some light investor     in  the metals  .
# ----
# interest interest_6
#  in  addition  ,  the effective    rate  on  the $ 410 million  of  total remaining bank debt  after  the restructuring  is  10.66 %  .
# ----
# interest interest_6
#  the combined effect  of  these changes  is expected to save  the company  about  $ 4 million  in     expenses  next  year  , or  six cents   a share  .
# ----
# interest interest_6
#  because  municipal bonds yields  have risen at  a time  when     rates  generally have fallen ,  some portfolio managers  are assuming that  bonds  bought now will appreciate in  value  as  the municipal bond market rebounds  .
# ----
# interest interest_6
#  ms. avedisian  believes that  the mutual funds  are selling  muni bonds   that  have  a negative convexity  --  those   that  have appreciated in  price  slowly relative to  the decline  in     rates  .
# ----
# interest interest_1
#  we  even invited  the public  to stop by and see  the program  , but there was n't  much     .
# ----
# interest interest_1
#  ''   advertisers  are showing      .
# ----
# interest interest_6
# ...
# ----
# interest interest_6
#  the financial services company  has been trying to avoid  a bankruptcy-law  filing since  it  failed to make     payments  in  june  on nearly  $ 1 billion  of  debt  .
# ----
# interest interest_1
#  but  sources  familiar with  mr. bass  say that after reviewing  the assets   he  lost      .
# ----
# interest interest_6
#  in  march 1988  ,  the central bank  began nudging     rates  higher in  an effort  to slow  economic activity  so that  prices  would moderate .
# ----
# interest interest_6
#  but  this spring  , after allowing  short-term    rates  to climb  three percentage points  ,  the fed reversed course  and started pushing  rates  down to protect  the slowing economy  from  a recession  .
# ----
# interests interest_5
#  kaneb pipe line partners l.p.  --  4.65 million units  , representing  senior preference limited partnership     , via  goldman sachs  .
# ----
# interest interest_5
#  for  example  ,  lincoln  sold  an equity     in  the project  to  american continental  ,  a purchase   the parent  financed with  proceeds  of ``  illusory transactions  with  lincoln subsidiaries  , '' according to  the suit  .
# ----
# interest interest_1
#  the investment banking concern  had to withdraw  a bond  offering for  ohio mattress co. last month  because of  lack  of  investor     .
# ----
# interests interest_5
#  henry kissinger  ,  who  has opposed  sanctions  against  china  and  who  has  extensive business     of  his own  in  china  , turned down  an invitation  to speak at  the event  .
# ----
# interest interest_1
#  according to  new american shoe  ,  the puerto rican government  has expressed      in keeping  the company 's factories  there operating , and has arranged for  private  and  government financial institutions  to discuss  local investment possiblities  with  the company  .
# ----
# interests interest_5
#  ge  also has      in  broadcasting  , lighting  products  ,  jet engines  ,  appliances  and  plastics  .
# ----
# interest interest_6
#  the delay  in getting  its lenders ' approval  of  the o&y loan  meant  campeau 's allied stores unit  missed  the    payment due friday  on  one series  of  junk bonds  .
# ----
# interest interest_6
#  allied  said  it  paid  the     on  its 10 14 % senior notes due 1992  but did n't pay  the *interest  on  its 11 12 % senior subordinated debentures due 1997  .
# ----
# interest interest_6
#  allied  did n't indicate  the amount  of  the overdue payment  , but  analysts  said  the aggregate    due friday  on  allied 's high-yield bonds  was about  $ 50 million  .
# ----
# interest interest_6
#  this week 's revision  of  the european currency unit  is n't likely to alter     rates  on  ecu-denominated securities  .
# ----
# interest interest_6
#  nevertheless , on  the surface   it  would seem  logical  for  ecu     rates to be higher than would otherwise be  the case  because of  higher inflation  in  spain  and  portugal  .
# ----
# interest interest_6
#  `` with  the inclusion  of  the peseta  and  escudo  ,  there  is apt to be  a rise  in  both   the short  - and  long-term    rates  since  the share  of  so-called soft-currency  or  high *interest countries  in  the currency basket  will increase , '' according to  a study  of  the ecu  by  ubs phillips  &  drew  .
# ----
# interest interest_6
#  according to  that study  , ``  the short-term ecu market    rate  after  the incorporation  of  the iberian currencies  will be about  85 basis points  above  the synthetical ecu reference *interest rate  , ''  which  does n't take  the peseta  and  escudo  into  consideration  .
# ----
# interest interest_6
#  as long as  foreign-exchange rates  between  the various european currencies  remain  stable  , then  fluctuations  in     rates  on  ecu-denominated securities  should respond mainly to  the changing fortunes  of  yields  in  the constituent credit markets  , with  the greatest influence  exerted by  west germany  ,  france  ,  the u.k.  and  italy  .
# ----
# interest interest_3
#  and in  a later scene  ,  we  see  shirer  chafing at  the folly  of being required by  cbs  to cover ``  human     ''  stories  like  the vienna boys ' choir  at  the very moment  of  the anschluss  .
# ----
# interest interest_6
#  the amount  of      saved through  the buy-back  could reach as much as  $ 100 million   a year  .
# ----
# interest interest_6
#  friday  ,  september 15  ,  1989    the key u.s.  and  foreign annual    rates  below are  a guide  to  general levels  but do n't always represent  actual transactions  .
# ----
# interest interest_5
#  united brands co.  said  it  sold  its 18.5 %     in  fii fyffes plc  ,  a distributor  of  fresh fruit  and  vegetables  , principally in  the united kingdom  .
# ----
# interest interest_1
#  mr. kerkorian  began trying to sell  MGMNP   some 18 months  ago , and  a long list  of  companies  expressed  an     , including  walt disney co.  ,  mca inc.  , and  davis cos.  , controlled by  marvin davis  .
# ----
# interests interest_4
#  still  unresolved  is  the key question  in  the case  : whether  rates  will be increased enough to satisfy  the     of  investors  in  the troubled utility  , or whether  increases  will be held down in  the *interests  of  the utility 's customers  .
# ----
# interests interest_4
#  still  unresolved  is  the key question  in  the case  : whether  rates  will be increased enough to satisfy  the *interests  of  investors  in  the troubled utility  , or whether  increases  will be held down in  the     of  the utility 's customers  .
# ----
# interest interest_6
#  ps  of  new hampshire  filed for  chapter 11 status  under  the federal bankruptcy code  in  january 1988  because  it   was n't  able to make     payments  on  its huge debt  , much of  which  was taken on to finance  its seabrook stake  .
# ----
# interest interest_6
#  in  the same period  ,  the so-called coverage ratio  of  service businesses  --  their cash flow  divided by  their    payments  -- fell to  2.3-to-1  from  4.5-to-1  .
# ----
# interest interest_1
#  environmental groups  have  no     in obtaining  winning fines  for  the treasury  , and will `` trade '' even  a  relatively  modest credit project  for  very high fines  .
# ----
# interest interest_6
#  in  a talk  to  big junk-bond buyers last week  ,  mr. milken  told  them   it  was  time  for  some companies  to  de-leverage  , urging  many companies  to swap  their junk debt  for  a combination  of  equity  and  higher-grade debt  carrying  a lower    burden  .
# ----
# interest interest_6
#  many investors   who  wanted to sell could n't find  any buyers  , and  there  were  widespread fears  that  some junk-bond financed companies  , despite  the  relatively  strong economy  , were close to defaulting on  their heavy    payments  .
# ----
# interest interest_6
#  but  mr. milken  , seemingly siding with  his critics   who  have argued that  many companies ' stock prices  have been held down by  the burdensome    payments  called for by  their junk bonds  , argues that  a shift  away from  junk  is now  the best way  for  investors  to make  money  .
# ----
# interest interest_6
#  integrated resources inc.  ,  a drexel client  , defaulted in  july  on nearly  $ 1 billion  in  debt  ;  resorts international inc.  failed to meet     payments  on  $ 925 million  in  junk debt  .
# ----
# interest interest_6
#  many junk-bond prices  tilted lower despite  a big drop  in     rates  and  no signs  of  recession  .
# ----
# interest interest_6
#  that debt  will cost  the company $ 600 million  to  $ 700 million  in     payments   a year  .
# ----
# interest interest_6
#  at  its current operating level  ,  analysts  say , united generates about  $ 1.1 billion  in  cash  annually to pay  its    bill  .
# ----
# interest interest_6
#  and because  its lenders  can deduct  50 %  of  the      they  earn on  ual 's loan  ,  the buy-out group  has been able to line up financing at  a more favorable *interest rate  .
# ----
# interests interest_4
#  ``  we  will vote  our claims  in  a way   that  suits  our customers '     , ''  he  says .
# ----
# interest interest_5
#  he  said  canfor  has  no plans  to boost  its     in  newsprint production  .
# ----
# interest interest_1
#  for  mr. davis  ,  ual  may become  the second major airline  to have eluded  his pursuit  ,  which  could intensify  questions  about  the seriousness  of  his     in making  acquisitions  .
# ----
# interest interest_6
#  confusion  is  the consequence  of  the long-hoped-for soft landing  , that  catch-all phrase   that  connotes moderating  economic growth  , declining  inflation  and  lower    rates  .
# ----
# interest interest_6
#  relatively  high    rates  are slowing  retail sales  , while manufacturing  inventories  are growing .
# ----
# interest interest_6
#  `` if  these problems  are cropping up now with  modest inflation  ,     rates  down and  the economy  expanding ,  what  in  god 's name  do  you  think will happen with extremely  tight money  and  an economic downturn  .
# ----
# interest interest_1
#  the company  said  others  besides  investor arthur goldberg  ,  who  is bidding  $ 32   a share  , have expressed      in buying  all  or  part  of  its operations  .
# ----
# interest interest_1
#  analysts  say  the weakness  in  the junk-bond market  is reducing      in  many takeover stocks  .
# ----
# interest interest_1
#  traders  say  a favorable article  on  the company 's orgotein painkiller  in  the current issue  of  the american journal  of  medicine  has spurred      in  the stock  , according to  dow jones professional investor report  .
# ----
# interest interest_6
#  the world bank loan  to  india  will be at  a variable    rate  , currently  7.74 %   a year  .
# ----
# interest interest_5
#  the facilities  include  a 70 %     in  the milford haven refinery  ,  250 service stations  and  *interests  in  an oil pipeline  and  five product terminals  .
# ----
# interests interest_5
#  the facilities  include  a 70 % *interest  in  the milford haven refinery  ,  250 service stations  and      in  an oil pipeline  and  five product terminals  .
# ----
# interest interest_1
#  the new publication  comes at  a time  of  increased     in  family business  among  major accounting firms  and  investment houses  .
# ----
# interest interest_6
#  cash-strapped lone star technologies inc.  ,  dallas  , said  it  made  an annual    payment due aug. 28  on  its $ 50 million  in  8 % convertible subordinated debentures due 2002  , preventing  a default  on  its debt  .
# ----
# interest interest_6
#  a company spokeswoman  said  there  was n't  a particular reason  why  the     was paid  last week  .
# ----
# interest interest_6
#  ``  the momentum  does n't seem to be enough to take  it  above  two... marks  '' now that     rate differentials  have narrowed .
# ----
# interest interest_6
#     rates  aside ,  central banks  remain  a primary obstacle  to  a stronger dollar  .
# ----
# interest interest_1
#  di giorgio corp.  ,  san francisco  , said ``  a number  of  third parties  '' have expressed      in  acquiring part  or  all  of  the food products  and  building materials  marketing and  distribution firm  .
# ----
# interest interest_1
#  di giorgio  said  the most recent expressions  of      are preliminary , but  it  said  the board  authorized  management  and  shearson lehman hutton inc.  ,  the firm 's financial adviser  , to continue to explore  alternatives  to  dig 's offer  and to seek  formal proposals  for  the sale  of  the entire company  or  some  of  its business units  .
# ----
# interest interest_1
#  british plaster board  closed at  255  , up  15  , on  new account  buying and talk of  possible takeover     in  the company  .
# ----
# interests interest_5
#  southmark  ,  which  has said  it  plans to sell  its health-care     as  part  of  its reorganization  under  federal bankruptcy laws  , opposed  the spinoffs  and began  a fight  to gain  control  of  national heritage 's board  .
# ----
# interest interest_5
#  prudential insurance co.  of  america  completed  its acquisition  of  merrill lynch  &  co. 's 75 %     in  fine homes international l.p.  for more than  $ 300 million  .
# ----
# interest interest_6
#  the world bank  and  its international development association unit  ,  which  makes  loans  and  grants  to  the poorest countries  , have  overdue principal  and     payments  on almost  $ 4 billion  of  loans  ,  an increase  from about  $ 3.4 billion  of  such troubled loans   the year  before .
# ----
# interest interest_1
#  for  his part  ,  the rev. ronald p. lengwin  ,  a spokesman  for  the catholic diocese  of  pittsburgh  , worries that  the show 's pilgrimage  to  the parish  will stir up  unwanted     in  the crucifix  again .
# ----
# interest interest_1
#  ruth may  ,  an administrative assistant  in  city hall   who  moved here in  1948  , laughs when asked about  television 's     in  the alien landing  .
# ----
# interest interest_6
#  congress president jerome kenyon  said  federated  and  allied  are n't behind in  their bills  , but  he  said  congress  was `` concerned  that campeau  would n't be able to meet  their    payments  .
# ----
# interest interest_6
#  ``  companies  in  greece  are currently paying  25 %  in     rates  and  bank charges  as opposed to around  6 %  abroad , '' said  dimitris economidis  ,  president  of  economdis electro-optics  ,  whose company  will be among  those  trading  otc  .
# ----
# interest interest_6
#  the revision  reflects  a slight  widening of  britain 's trade surplus  in  services  , particularly in  tourism  , and  a narrowing  of  the surplus  in      ,  profits  and  dividends  .
# ----
# interest interest_6
#  alpine group inc.  , aiming to cut     costs  , will offer  a package  of  cash  and  securities  for  its $ 43.7 million debt  outstanding .
# ----
# interest interest_6
#  alpine  would save  some $ 2 million   a year  in     costs  if  80 %  of  debentures  are exchanged and  $ 2.5 million  if  100 %  are exchanged , said  steven s. elbaum  ,  chairman  and  chief executive officer  .
# ----
# interests interest_5
#  other properties  include  the company 's entire oil-and-gas assets  in  dubai  ,  gabon  and  italy  plus  certain     in  ecuador  ,  columbia  and  indonesia  .
# ----
# interest interest_1
#  earlier  this month  ,  van kampen merritt  ,  an investment banking unit  of  xerox corp.  , announced  a bid  to buy  syncor 's  for about  $ 81.8 million  , but  it  dropped  the bid  due to  syncor 's lack  of      .
# ----
# interest interest_6
#  ``  lower    rates  and  discount pricing  have led to  a rebound  in spending on  consumer durables  , '' said  william k. mac-reynolds  ,  director  of  economic forecasting  at  the u.s. chamber  of  commerce  .
# ----
# interest interest_6
#  bell atlantic  also will be refinancing  the debt  on  three  of  its telephone company units  to take  advantage  of  lower    rates  , in  the hope  of  improving cash flow  .
# ----
# interests interest_5
#  mr. kissinger 's     include  a limited partnership  called  china ventures  .
# ----
# interests interest_3
#  it  's hard to tell at  times  where  such cultural activities end  and  mr. kissinger 's business     begin .
# ----
# interest interest_4
#  mr. kissinger  adds that  his public comments  about  china  represent  his sense  of  what  is best for  the u.s. national     .
# ----
# interests interest_4
#  ``  his sense  is that  you  have to be restrained in intervening with  the internal affairs  of  another country  , and  you  also have to be aware of  long-term geopolitical      that  may be at  risk  , '' says  winston lord  ,  a former kissinger protege   who  was  ambassador  to  china  from  1985  to  1989  .
# ----
# interest interest_5
#  mr. lord  adds that although  he  does n't fully share  mr. kissinger 's sympathy  for  the deng regime  ,  he  is convinced that  mr. kissinger 's views  are n't influenced by  money  : `` if  he  did n't have  a cent  of  commercial     in  china  ,  he  would have taken  the same position  .
# ----

# %%
with open('new_train/interest.cor') as f:
    d = {}
    for i in xrange(6):
        key = 'interest_{}'.format(i+1)
        d[key] = []
    for line in f.readlines():
        m = re.search("<s>(.*)<\/s>", line)
        if m:
            m2 = re.search("<tag \"(.*)\">(.*)<\/>", line)
            if m2:
                meaning = m2.group(1)
                word = m2.group(2)
                sentence = m.group(1)
                sentence = sentence.replace(m2.group(0), '')
                d[meaning].append(sentence)

# %%
for key in d.keys():
    print len(d[key])
# Out:
# 500
# 178
# 1252
# 361
# 66
# 11
